# %% [markdown]
# # Load Data

# %%
import re
import ssl

import pandas as pd
import numpy as np
import tqdm
from scipy.stats import chi2_contingency

import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize

ssl._create_default_https_context = ssl._create_unverified_context
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)

from langdetect import detect

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy

from pprint import pprint

# %%
# load data
lords = pd.read_csv('/Users/javier/Desktop/cmgt-597/steam-review-data/lords_df.csv') # Lords of the Fallen
lords.shape
# Out:
# (14509, 8)

# %%
# filter helpful and actual reviews
# note: weighted_vote_score measures how helpful a review is. so reviews with a weighted_vote_score of 0 are filtered out

lords_df = lords[(lords['weighted_vote_score'] != 0.0) & # helpful reviews only
             (lords['playtime_at_review'] != 0.0) & # actual reviews only (can't review a game you never played!)
             (lords['review'].notnull()) # reviews with words only
             ]

lords_reviews = lords_df[['recommendationid', 'review', 'voted_up']]
lords_reviews
# Out:
#       recommendationid                                             review  \
# 0            148136042  Having issues with performance? \n\nChange bot...
# 1            148896243  This is a 'Souls-Like' through and through, if...
# 2            148457883  Giving this a positive review because it's gen...
# 3            148328489  This game is honestly way better than I origin...
# 4            148383765  This game has some of the most incredible vist...
# ...                ...                                                ...
# 6312         148177186  This game is absolute trash..\n\nYou should pl...
# 6313         148157180  after hour and half to learn controls and play...
# 6314         149433369                        I'm gooning in Umbral Realm
# 6315         148133087         released 5 minutes late, actually seething
# 6316         148203559  DO NOT BUY GAME IS FCKING TRASH and i feel sor...
#
#       voted_up
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ...        ...
# 6312     False
# 6313      True
# 6314      True
# 6315     False
# 6316     False
#
# [6307 rows x 3 columns]

# %% [markdown]
# # Text Prep

# %%
# First tokenize each sentence into a list of words, removing punctuations and unnecessary characters altogether

def sent_to_words(sentences): # define function sent_to_words (sentences to words), argument is the dataframe and column of your reviews.
    for sentence in sentences: # for every sentence (review) in the sentences (review df)
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations  | # use the gensim package to tokenize your reviews

lords_reviews['data_words'] = list(sent_to_words(lords_reviews['review'])) # declare a new column in the lop_review df called 'data_words'
                                                                        # then use the sent_to_words function to tokenize the review column of the lop_review df
# Out:
# /var/folders/g7/4gfvqn6x20b94nl8zqc5vl6h0000gn/T/ipykernel_76529/1110368638.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lords_reviews['data_words'] = list(sent_to_words(lords_reviews['review'])) # declare a new column in the lop_review df called 'data_words'

# %%
# After tokenization remove stoword and apply lemmatization 

stop_words = stopwords.words('english') # declare english as the stopword language
# stop_words.extend(['app', 'bank', 'account','try','issue','problem', 'face'])  #adding my own stop words

def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']): # define function process_words. arguments are the column of the tokenized words,
                                                                                                 # stop words library, allowed_postags
    # remove stop words
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts] # remove stop words from tokenized reviews
    texts_out = [] # define variable texts_out. it is an empty list.

    # Lemmatization
    nlp = spacy.load("en_core_web_sm",disable=['parser', 'ner']) # define variable nlp. this is for lemmatization
    for sent in texts: # for every sentence in texts (review df)
        doc = nlp(" ".join(sent)) # declare variable doc
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags]) # append the lemmatized words to the texts_out empty list
    
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out] # remove stopwords again
    return texts_out # return the texts_out list

lords_reviews['data_ready'] = process_words(lords_reviews['data_words'])  # processed Text Data!
# Out:
# /var/folders/g7/4gfvqn6x20b94nl8zqc5vl6h0000gn/T/ipykernel_76529/4192719038.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lords_reviews['data_ready'] = process_words(lords_reviews['data_words'])  # processed Text Data!

# %%
# cleaning the reviews further to remove non-English text

def detect_my(text):
    try:
        return detect(text)
    except:
        return 'unknown'
    
lords_reviews['language'] = lords_reviews['review'].apply(detect_my)
# Out:
# /var/folders/g7/4gfvqn6x20b94nl8zqc5vl6h0000gn/T/ipykernel_76529/2918186834.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lords_reviews['language'] = lords_reviews['review'].apply(detect_my)

# %%
lords_reviews
# Out:
#       recommendationid                                             review  \
# 0            148136042  Having issues with performance? \n\nChange bot...
# 1            148896243  This is a 'Souls-Like' through and through, if...
# 2            148457883  Giving this a positive review because it's gen...
# 3            148328489  This game is honestly way better than I origin...
# 4            148383765  This game has some of the most incredible vist...
# ...                ...                                                ...
# 6312         148177186  This game is absolute trash..\n\nYou should pl...
# 6313         148157180  after hour and half to learn controls and play...
# 6314         149433369                        I'm gooning in Umbral Realm
# 6315         148133087         released 5 minutes late, actually seething
# 6316         148203559  DO NOT BUY GAME IS FCKING TRASH and i feel sor...
#
#       voted_up                                         data_words  \
# 0         True  [having, issues, with, performance, change, bo...
# 1         True  [this, is, souls, like, through, and, through,...
# 2         True  [giving, this, positive, review, because, it, ...
# 3         True  [this, game, is, honestly, way, better, than, ...
# 4         True  [this, game, has, some, of, the, most, incredi...
# ...        ...                                                ...
# 6312     False  [this, game, is, absolute, trash, you, should,...
# 6313      True  [after, hour, and, half, to, learn, controls, ...
# 6314      True                       [gooning, in, umbral, realm]
# 6315     False      [released, minutes, late, actually, seething]
# 6316     False  [do, not, buy, game, is, fcking, trash, and, f...
#
#                                              data_ready language
# 0     [issue, performance, change, reflection, globa...       en
# 1     [soul, willing, take, leap, faith, good, tackl...       en
# 2     [give, positive, review, genuinely, great, als...       en
# 3     [game, honestly, way, well, originally, expect...       en
# 4     [game, incredible, vista, see, video, game, co...       en
# ...                                                 ...      ...
# 6312     [game, absolute, trash, play, literally, game]       en
# 6313    [hour, half, learn, control, playing, go, love]       en
# 6314                             [goone, umbral, realm]       tl
# 6315          [release, minute, late, actually, seethe]       en
# 6316  [buy, game, fcking, trash, feel, sorry, preord...       en
#
# [6307 rows x 6 columns]

# %%
drop_languages = ['ar', 'fa', 'hi', 'hu', 'ko', 'pt', 'ru', 'uk', 'zh-cn'] # these review tagged with these languages are not in English

lords_reviews = lords_reviews[(~lords_reviews['language'].isin(drop_languages)) &
                          ~((lords_reviews['language'] == 'unknown') & (lords_reviews['data_ready'].apply(len) == 0))
                          ]

lords_reviews = lords_reviews.drop(columns='language')

# %%
lords_reviews
# Out:
#       recommendationid                                             review  \
# 0            148136042  Having issues with performance? \n\nChange bot...
# 1            148896243  This is a 'Souls-Like' through and through, if...
# 2            148457883  Giving this a positive review because it's gen...
# 3            148328489  This game is honestly way better than I origin...
# 4            148383765  This game has some of the most incredible vist...
# ...                ...                                                ...
# 6312         148177186  This game is absolute trash..\n\nYou should pl...
# 6313         148157180  after hour and half to learn controls and play...
# 6314         149433369                        I'm gooning in Umbral Realm
# 6315         148133087         released 5 minutes late, actually seething
# 6316         148203559  DO NOT BUY GAME IS FCKING TRASH and i feel sor...
#
#       voted_up                                         data_words  \
# 0         True  [having, issues, with, performance, change, bo...
# 1         True  [this, is, souls, like, through, and, through,...
# 2         True  [giving, this, positive, review, because, it, ...
# 3         True  [this, game, is, honestly, way, better, than, ...
# 4         True  [this, game, has, some, of, the, most, incredi...
# ...        ...                                                ...
# 6312     False  [this, game, is, absolute, trash, you, should,...
# 6313      True  [after, hour, and, half, to, learn, controls, ...
# 6314      True                       [gooning, in, umbral, realm]
# 6315     False      [released, minutes, late, actually, seething]
# 6316     False  [do, not, buy, game, is, fcking, trash, and, f...
#
#                                              data_ready
# 0     [issue, performance, change, reflection, globa...
# 1     [soul, willing, take, leap, faith, good, tackl...
# 2     [give, positive, review, genuinely, great, als...
# 3     [game, honestly, way, well, originally, expect...
# 4     [game, incredible, vista, see, video, game, co...
# ...                                                 ...
# 6312     [game, absolute, trash, play, literally, game]
# 6313    [hour, half, learn, control, playing, go, love]
# 6314                             [goone, umbral, realm]
# 6315          [release, minute, late, actually, seethe]
# 6316  [buy, game, fcking, trash, feel, sorry, preord...
#
# [6225 rows x 5 columns]

# %% [markdown]
# # Base LDA Model

# %%
# Create the Dictionary and Corpus needed for Topic Modelling


#  Dictionary
id2word = corpora.Dictionary(lords_reviews['data_ready'])

#  Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in lords_reviews['data_ready']]

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                            id2word=id2word,
                                            num_topics=10, 
                                            random_state=100,
                                            chunksize=100,
                                            passes=10,
                                            per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.106*"ring" + 0.100*"elden" + 0.099*"soul" + 0.097*"game" + 0.068*"good" + '
#   '0.059*"dark" + 0.036*"bad" + 0.035*"play" + 0.032*"well" + 0.025*"buy"'),
#  (1,
#   '0.006*"seemless" + 0.006*"meaning" + 0.005*"working" + 0.001*"candy" + '
#   '0.000*"tomorrow" + 0.000*"rad" + 0.000*"bb" + 0.000*"fecking" + '
#   '0.000*"rollback" + 0.000*"sack"'),
#  (2,
#   '0.018*"feel" + 0.017*"attack" + 0.016*"lock" + 0.013*"control" + '
#   '0.012*"garbage" + 0.011*"combat" + 0.011*"character" + 0.010*"make" + '
#   '0.010*"animation" + 0.010*"hit"'),
#  (3,
#   '0.091*"fall" + 0.072*"lord" + 0.035*"soul" + 0.020*"experience" + '
#   '0.015*"title" + 0.015*"dark" + 0.015*"genre" + 0.012*"love" + 0.011*"game" '
#   '+ 0.010*"challenge"'),
#  (4,
#   '0.073*"op" + 0.057*"co" + 0.041*"friend" + 0.040*"host" + '
#   '0.027*"multiplayer" + 0.027*"player" + 0.026*"coop" + 0.026*"play" + '
#   '0.021*"get" + 0.018*"seamless"'),
#  (5,
#   '0.114*"game" + 0.026*"play" + 0.017*"get" + 0.015*"run" + 0.015*"issue" + '
#   '0.014*"review" + 0.014*"performance" + 0.012*"crash" + 0.010*"update" + '
#   '0.010*"good"'),
#  (6,
#   '0.072*"shit" + 0.043*"fucking" + 0.038*"trash" + 0.033*"suck" + '
#   '0.031*"fuck" + 0.025*"dog" + 0.019*"kinda" + 0.014*"sub" + 0.013*"piece" + '
#   '0.011*"straight"'),
#  (7,
#   '0.039*"game" + 0.031*"world" + 0.029*"feel" + 0.026*"soul" + 0.022*"design" '
#   '+ 0.021*"good" + 0.020*"combat" + 0.017*"really" + 0.017*"mechanic" + '
#   '0.016*"great"'),
#  (8,
#   '0.046*"game" + 0.024*"boss" + 0.024*"enemy" + 0.020*"get" + 0.013*"make" + '
#   '0.011*"time" + 0.011*"go" + 0.010*"even" + 0.009*"fight" + 0.009*"bad"'),
#  (9,
#   '0.023*"good" + 0.020*"cancer" + 0.019*"gud" + 0.016*"price" + 0.015*"brain" '
#   '+ 0.015*"grind" + 0.014*"average" + 0.014*"bad" + 0.014*"life" + '
#   '0.012*"story"')]

# %%
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

coherence_model_lda = CoherenceModel(model=lda_model, texts=lords_reviews['data_ready'], dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.467307780209206
#
# Coherence Score:  0.4109652903667495

# %% [markdown]
# # Hyperparameter Tuning

# %%
def compute_coherence_values(corpus, dictionary, k, a, b):
    
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, # changed the LDA method to Rolly John's
                                                id2word=dictionary,
                                                num_topics=k, 
                                                random_state=100,
                                                chunksize=100,
                                                passes=10,
                                                alpha=a,
                                                eta=b)
    
    coherence_model_lda = CoherenceModel(model=lda_model, texts=lords_reviews['data_ready'], dictionary=id2word, coherence='c_v')
    
    return coherence_model_lda.get_coherence()

# %%
grid = {}
grid['Validation_Set'] = {}

# Topics range
min_topics = 2
max_topics = 11
step_size = 1
topics_range = range(min_topics, max_topics, step_size)

# Alpha parameter
alpha = list(np.arange(0.01, 1, 0.3))
alpha.append('symmetric')
alpha.append('asymmetric')

# Beta parameter
beta = list(np.arange(0.01, 1, 0.3))
beta.append('symmetric')

# Validation sets
num_of_docs = len(corpus)
corpus_sets = [gensim.utils.ClippedCorpus(corpus, int(num_of_docs*0.75)), 
               corpus]

corpus_title = ['75% Corpus', '100% Corpus']

model_results = {'Validation_Set': [],
                 'Topics': [],
                 'Alpha': [],
                 'Beta': [],
                 'Coherence': []
                }

# Can take a long time to run
if 1 == 1:
    pbar = tqdm.tqdm(total=(len(beta)*len(alpha)*len(topics_range)*len(corpus_title)))
    
    # iterate through validation corpuses
    for i in range(len(corpus_sets)):
        # iterate through number of topics
        for k in topics_range:
            # iterate through alpha values
            for a in alpha:
                # iterare through beta values
                for b in beta:
                    # get the coherence score for the given parameters
                    cv = compute_coherence_values(corpus=corpus_sets[i], dictionary=id2word, 
                                                  k=k, a=a, b=b)
                    # Save the model results
                    model_results['Validation_Set'].append(corpus_title[i])
                    model_results['Topics'].append(k)
                    model_results['Alpha'].append(a)
                    model_results['Beta'].append(b)
                    model_results['Coherence'].append(cv)
                    
                    pbar.update(1)

    # pd.DataFrame(model_results).to_csv('./results/lda_tuning_results.csv', index=False)
                    
    lda_tuning_results = pd.DataFrame(model_results)

    file_name = 'lords-lda-tuning-results.csv'

    lda_tuning_results.to_csv(f'{file_name}', index = False)
    output_filepath = f'/Users/javier/Desktop/cmgt-597/lords-of-the-fallen/{file_name}'
    lda_tuning_results.to_csv(output_filepath, index = False)
    
    pbar.close()

# %%
lda_tuning_results = pd.read_csv('/Users/javier/Desktop/cmgt-597/lords-of-the-fallen/lords-lda-tuning-results.csv')
lda_tuning_results

# %% [markdown]
# # Final Model

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                            id2word=id2word,
                                            num_topics=9, 
                                            random_state=100,
                                            chunksize=100,
                                            passes=10,
                                            alpha=0.01,
                                            eta=0.6)
                                            #the alpha and beta will yield the highest coherence score, according to the tuning results
                                            

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.003*"poop" + 0.002*"bucket" + 0.001*"cheek" + 0.001*"pet" + 0.001*"dog" + '
#   '0.001*"fever" + 0.001*"mucho" + 0.001*"tiene" + 0.001*"wah" + 0.001*"werk"'),
#  (1,
#   '0.005*"grind" + 0.003*"average" + 0.003*"paint" + 0.003*"dry" + '
#   '0.003*"long" + 0.002*"spare" + 0.002*"brain" + 0.002*"adult" + 0.002*"boi" '
#   '+ 0.002*"easy"'),
#  (2,
#   '0.010*"cancer" + 0.005*"disorder" + 0.004*"disease" + 0.004*"syndrome" + '
#   '0.003*"anal" + 0.002*"infection" + 0.001*"prostate" + 0.001*"personality" + '
#   '0.001*"cold" + 0.001*"fatigue"'),
#  (3,
#   '0.004*"brown" + 0.004*"pink" + 0.002*"birth" + 0.002*"unclean" + '
#   '0.002*"atmospheric" + 0.002*"rpgs" + 0.002*"strategic" + 0.001*"depth" + '
#   '0.001*"glory" + 0.001*"shave"'),
#  (4,
#   '0.048*"op" + 0.039*"co" + 0.027*"host" + 0.013*"seamless" + 0.012*"friend" '
#   '+ 0.006*"coop" + 0.005*"item" + 0.005*"guest" + 0.004*"loot" + '
#   '0.004*"partner"'),
#  (5,
#   '0.083*"game" + 0.021*"play" + 0.013*"good" + 0.013*"get" + 0.013*"soul" + '
#   '0.009*"run" + 0.009*"issue" + 0.009*"performance" + 0.009*"bad" + '
#   '0.009*"well"'),
#  (6,
#   '0.004*"interste" + 0.001*"nur" + 0.001*"ist" + 0.001*"crossing" + '
#   '0.001*"animal" + 0.001*"ama" + 0.001*"sig" + 0.001*"vrutna" + 0.001*"nqma" '
#   '+ 0.001*"godkiller"'),
#  (7,
#   '0.001*"eyesight" + 0.001*"crusade" + 0.001*"vraiment" + 0.001*"avaient" + '
#   '0.001*"frustrant" + 0.001*"moin" + 0.001*"paque" + 0.001*"error" + '
#   '0.001*"penetration" + 0.001*"appointment"'),
#  (8,
#   '0.036*"game" + 0.016*"enemy" + 0.015*"boss" + 0.011*"get" + 0.009*"feel" + '
#   '0.009*"make" + 0.009*"soul" + 0.007*"time" + 0.007*"world" + 0.007*"bad"')]

# %%
# Final Model Evaluation
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

coherence_model_lda = CoherenceModel(model=lda_model, texts=lords_reviews['data_ready'], dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.164313506560036
#
# Coherence Score:  0.5271473191212089

# %% [markdown]
# # Topic-Review Allocation

# %%
def format_topics_sentences(ldamodel=None, corpus=None, texts=None):
    # Initialize an empty list to store data
    data = []

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        
        # Initialize variables to store topic information
        dominant_topic = None
        perc_contribution = None
        topic_keywords = None
        
        # Loop through topics in the row
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                dominant_topic = int(topic_num)
                perc_contribution = round(prop_topic, 4)
                break
        
        # Store the extracted information
        data.append([dominant_topic, perc_contribution, topic_keywords])

    # Convert the list of data into a DataFrame
    sent_topics_df = pd.DataFrame(data, columns=['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords'])

    # Add original text to the end of the output
    contents = pd.Series(texts)
    contents.reset_index(drop=True, inplace=True)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return sent_topics_df

# Call the function with appropriate arguments
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=lords_reviews.review)

# Format the DataFrame
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'review']

# Display the first 5 rows of the DataFrame
display(df_dominant_topic.head(5))
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0               5              0.9947
# 1            1               5              0.5895
# 2            2               5              0.9953
# 3            3               8              0.9988
# 4            4               8              0.8843
#
#                                             Keywords  \
# 0  game, play, good, get, soul, run, issue, perfo...
# 1  game, play, good, get, soul, run, issue, perfo...
# 2  game, play, good, get, soul, run, issue, perfo...
# 3  game, enemy, boss, get, feel, make, soul, time...
# 4  game, enemy, boss, get, feel, make, soul, time...
#
#                                               review
# 0  Having issues with performance? \n\nChange bot...
# 1  This is a 'Souls-Like' through and through, if...
# 2  Giving this a positive review because it's gen...
# 3  This game is honestly way better than I origin...
# 4  This game has some of the most incredible vist...

# %%
lords_reviews = df_dominant_topic.merge(lords_reviews, how='left')
lords_reviews.drop_duplicates(subset=['Document_No'], keep='first', inplace=True)

# %%
lords_reviews = lords_reviews[['Document_No', 'review', 'data_words', 'data_ready', 'Keywords', 'Dominant_Topic', 'Topic_Perc_Contrib', 'voted_up']]

# %%
# final dataframe
lords_reviews
# Out:
#       Document_No                                             review  \
# 0               0  Having issues with performance? \n\nChange bot...
# 1               1  This is a 'Souls-Like' through and through, if...
# 2               2  Giving this a positive review because it's gen...
# 3               3  This game is honestly way better than I origin...
# 4               4  This game has some of the most incredible vist...
# ...           ...                                                ...
# 6632         6220  This game is absolute trash..\n\nYou should pl...
# 6633         6221  after hour and half to learn controls and play...
# 6634         6222                        I'm gooning in Umbral Realm
# 6635         6223         released 5 minutes late, actually seething
# 6636         6224  DO NOT BUY GAME IS FCKING TRASH and i feel sor...
#
#                                              data_words  \
# 0     [having, issues, with, performance, change, bo...
# 1     [this, is, souls, like, through, and, through,...
# 2     [giving, this, positive, review, because, it, ...
# 3     [this, game, is, honestly, way, better, than, ...
# 4     [this, game, has, some, of, the, most, incredi...
# ...                                                 ...
# 6632  [this, game, is, absolute, trash, you, should,...
# 6633  [after, hour, and, half, to, learn, controls, ...
# 6634                       [gooning, in, umbral, realm]
# 6635      [released, minutes, late, actually, seething]
# 6636  [do, not, buy, game, is, fcking, trash, and, f...
#
#                                              data_ready  \
# 0     [issue, performance, change, reflection, globa...
# 1     [soul, willing, take, leap, faith, good, tackl...
# 2     [give, positive, review, genuinely, great, als...
# 3     [game, honestly, way, well, originally, expect...
# 4     [game, incredible, vista, see, video, game, co...
# ...                                                 ...
# 6632     [game, absolute, trash, play, literally, game]
# 6633    [hour, half, learn, control, playing, go, love]
# 6634                             [goone, umbral, realm]
# 6635          [release, minute, late, actually, seethe]
# 6636  [buy, game, fcking, trash, feel, sorry, preord...
#
#                                                Keywords  Dominant_Topic  \
# 0     game, play, good, get, soul, run, issue, perfo...               5
# 1     game, play, good, get, soul, run, issue, perfo...               5
# 2     game, play, good, get, soul, run, issue, perfo...               5
# 3     game, enemy, boss, get, feel, make, soul, time...               8
# 4     game, enemy, boss, get, feel, make, soul, time...               8
# ...                                                 ...             ...
# 6632  game, play, good, get, soul, run, issue, perfo...               5
# 6633  game, play, good, get, soul, run, issue, perfo...               5
# 6634  game, enemy, boss, get, feel, make, soul, time...               8
# 6635  game, play, good, get, soul, run, issue, perfo...               5
# 6636  game, play, good, get, soul, run, issue, perfo...               5
#
#       Topic_Perc_Contrib  voted_up
# 0                 0.9947      True
# 1                 0.5895      True
# 2                 0.9953      True
# 3                 0.9988      True
# 4                 0.8843      True
# ...                  ...       ...
# 6632              0.9869     False
# 6633              0.9887      True
# 6634              0.9741      True
# 6635              0.9843     False
# 6636              0.9978     False
#
# [6225 rows x 8 columns]

# %%
file_name = 'lords-lda.csv'

lords_reviews.to_csv(f'{file_name}', index = False)
output_filepath = f'/Users/javier/Desktop/cmgt-597/lords-of-the-fallen/{file_name}'
lords_reviews.to_csv(output_filepath, index = False)

# %% [markdown]
# # Data Analysis

# %%
lords_lda_final = pd.read_csv('/Users/javier/Desktop/cmgt-597/lords-of-the-fallen/lords-lda.csv')
lords_lda_final
# Out:
#       Document_No                                             review  \
# 0               0  Having issues with performance? \n\nChange bot...
# 1               1  This is a 'Souls-Like' through and through, if...
# 2               2  Giving this a positive review because it's gen...
# 3               3  This game is honestly way better than I origin...
# 4               4  This game has some of the most incredible vist...
# ...           ...                                                ...
# 6220         6220  This game is absolute trash..\n\nYou should pl...
# 6221         6221  after hour and half to learn controls and play...
# 6222         6222                        I'm gooning in Umbral Realm
# 6223         6223         released 5 minutes late, actually seething
# 6224         6224  DO NOT BUY GAME IS FCKING TRASH and i feel sor...
#
#                                              data_words  \
# 0     ['having', 'issues', 'with', 'performance', 'c...
# 1     ['this', 'is', 'souls', 'like', 'through', 'an...
# 2     ['giving', 'this', 'positive', 'review', 'beca...
# 3     ['this', 'game', 'is', 'honestly', 'way', 'bet...
# 4     ['this', 'game', 'has', 'some', 'of', 'the', '...
# ...                                                 ...
# 6220  ['this', 'game', 'is', 'absolute', 'trash', 'y...
# 6221  ['after', 'hour', 'and', 'half', 'to', 'learn'...
# 6222               ['gooning', 'in', 'umbral', 'realm']
# 6223  ['released', 'minutes', 'late', 'actually', 's...
# 6224  ['do', 'not', 'buy', 'game', 'is', 'fcking', '...
#
#                                              data_ready  \
# 0     ['issue', 'performance', 'change', 'reflection...
# 1     ['soul', 'willing', 'take', 'leap', 'faith', '...
# 2     ['give', 'positive', 'review', 'genuinely', 'g...
# 3     ['game', 'honestly', 'way', 'well', 'originall...
# 4     ['game', 'incredible', 'vista', 'see', 'video'...
# ...                                                 ...
# 6220  ['game', 'absolute', 'trash', 'play', 'literal...
# 6221  ['hour', 'half', 'learn', 'control', 'playing'...
# 6222                       ['goone', 'umbral', 'realm']
# 6223  ['release', 'minute', 'late', 'actually', 'see...
# 6224  ['buy', 'game', 'fcking', 'trash', 'feel', 'so...
#
#                                                Keywords  Dominant_Topic  \
# 0     fps, setting, run, hate, ultra, high, low, gra...               2
# 1     game, enemy, boss, soul, get, feel, good, make...               6
# 2     game, play, get, crash, review, good, issue, b...               5
# 3     game, enemy, boss, soul, get, feel, good, make...               6
# 4     game, enemy, boss, soul, get, feel, good, make...               6
# ...                                                 ...             ...
# 6220  game, play, get, crash, review, good, issue, b...               5
# 6221  game, enemy, boss, soul, get, feel, good, make...               6
# 6222  game, enemy, boss, soul, get, feel, good, make...               6
# 6223  game, play, get, crash, review, good, issue, b...               5
# 6224  game, play, get, crash, review, good, issue, b...               5
#
#       Topic_Perc_Contrib  voted_up
# 0                 0.8939      True
# 1                 0.8535      True
# 2                 0.9953      True
# 3                 0.9988      True
# 4                 0.8887      True
# ...                  ...       ...
# 6220              0.9869     False
# 6221              0.9887      True
# 6222              0.9741      True
# 6223              0.7994     False
# 6224              0.8546     False
#
# [6225 rows x 8 columns]

# %%
# distribution of topics across reviews

topic_count = lords_lda_final['Dominant_Topic'].value_counts()
topic_count
# Out:
# Dominant_Topic
# 6    3532
# 5    2316
# 2     169
# 0      97
# 3      44
# 1      23
# 8      17
# 7      15
# 4      12
# Name: count, dtype: int64

# %%
# Visualize topics

import pyLDAvis
import pyLDAvis.gensim

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 8     -0.285483 -0.098048       1        1  65.673560
# 5     -0.307084  0.092531       2        1  31.614787
# 4      0.089501 -0.009916       3        1   1.426120
# 3      0.087697 -0.002020       4        1   0.408713
# 1      0.074053  0.001626       5        1   0.389311
# 2      0.090930  0.006183       6        1   0.167075
# 7      0.084458  0.003617       7        1   0.141655
# 0      0.082662  0.002386       8        1   0.105134
# 6      0.083266  0.003640       9        1   0.073647, topic_info=           Term          Freq         Total Category  logprob  loglift
# 1          game  17252.000000  17252.000000  Default  30.0000  30.0000
# 56         play   3729.000000   3729.000000  Default  29.0000  29.0000
# 189       enemy   3641.000000   3641.000000  Default  28.0000  28.0000
# 359        item    651.000000    651.000000  Default  27.0000  27.0000
# 412          op    274.000000    274.000000  Default  26.0000  26.0000
# ...         ...           ...           ...      ...      ...      ...
# 11283     handl      0.146252      3.557507   Topic9  -7.4560   4.0222
# 11284    myslef      0.146252      3.557507   Topic9  -7.4560   4.0222
# 11285  probliem      0.146252      3.557507   Topic9  -7.4560   4.0222
# 4119   nintendo      0.162223      9.126875   Topic9  -7.3523   3.1836
# 3760        sum      0.172544     34.589640   Topic9  -7.2906   1.9130
#
# [485 rows x 6 columns], token_table=       Topic      Freq         Term
# term
# 11322      1  0.366333  abnormality
# 11322      2  0.366333  abnormality
# 11323      1  0.366333      abscess
# 11323      2  0.366333      abscess
# 5296       1  0.563333      absence
# ...      ...       ...          ...
# 11159      2  0.277618       writin
# 10999      1  0.353524         yess
# 10999      2  0.353524         yess
# 11461      1  0.384519          yum
# 11461      2  0.384519          yum
#
# [1081 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[9, 6, 5, 4, 2, 3, 8, 1, 7])

# %% [markdown]
# ---
